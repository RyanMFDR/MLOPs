# %%
# !pip install nltk spacy pandas

# %%
import pandas as pd
import nltk
import spacy
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv("JPTIIK.csv")

# %%
df = pd.read_csv(file_path)
print(df.head())
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0    1739944760-452  https://j-ptiik.ub.ac.id/index.php/j-ptiik/iss...
# 1    1739944760-453  https://j-ptiik.ub.ac.id/index.php/j-ptiik/iss...
# 2    1739944762-454  https://j-ptiik.ub.ac.id/index.php/j-ptiik/iss...
# 3    1739944762-455  https://j-ptiik.ub.ac.id/index.php/j-ptiik/iss...
# 4    1739944762-456  https://j-ptiik.ub.ac.id/index.php/j-ptiik/iss...
#
#                         jurnal  \
# 0  Publikasi Khusus Tahun 2023
# 1  Publikasi Khusus Tahun 2023
# 2  Publikasi Khusus Tahun 2023
# 3  Publikasi Khusus Tahun 2023
# 4  Publikasi Khusus Tahun 2023
#
#                                          jurnal-href  \
# 0  https://j-ptiik.ub.ac.id/index.php/j-ptiik/iss...
# 1  https://j-ptiik.ub.ac.id/index.php/j-ptiik/iss...
# 2  https://j-ptiik.ub.ac.id/index.php/j-ptiik/iss...
# 3  https://j-ptiik.ub.ac.id/index.php/j-ptiik/iss...
# 4  https://j-ptiik.ub.ac.id/index.php/j-ptiik/iss...
#
# ...

# %%
print("Kolom di dataset:", df.columns.tolist())
# Out:
# Kolom di dataset: ['web-scraper-order', 'web-scraper-start-url', 'jurnal', 'jurnal-href', 'artikel', 'artikel-href', 'title', 'penulis']

# %%
kolom_judul = "title"
kolom_penulis = "penulis"

# %%
df = df[[kolom_judul, kolom_penulis]].dropna()

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %%
def preprocess_text(text):
    # Tokenisasi
    tokens = word_tokenize(text.lower())  # Konversi ke lowercase

    # Stopword Removal
    stop_words = set(stopwords.words("english"))  # Ganti "indonesian" jika pakai bahasa Indonesia
    tokens = [word for word in tokens if word.isalnum() and word not in stop_words]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return " ".join(tokens)

# %%
output_path = "JPTIIK_cleaned_sorted.csv"
df.to_csv(output_path, index=False)

# %%
from IPython.display import display
display(df)

print("Cleaned Data:", output_path)
# Out:
#                                                   title  \
# 2778  Aanlisis Prediksi Kemampuan Pembayaran Klien H...
# 2777  Aanlisis Prediksi Kemampuan Pembayaran Klien H...
# 2779  Aanlisis Prediksi Kemampuan Pembayaran Klien H...
# 2103  Akses Kendaraan pada Perumahan menggunakan Blu...
# 2104  Akses Kendaraan pada Perumahan menggunakan Blu...
# ...                                                 ...
# 1110  Uji Kinerja Host-Based Intrution Detection Sys...
# 1109  Uji Kinerja Host-Based Intrution Detection Sys...
# 1108  Uji Kinerja Host-Based Intrution Detection Sys...
# 589   Visualisasi Topologi Routing pada Jaringan ber...
# 588   Visualisasi Topologi Routing pada Jaringan ber...
#
#                         penulis  \
# 2778              Bayu Rahayudi
# 2777         Abrilian Maulidhia
# 2779              Welly Purnomo
# 2103              Zulfi Alfariz
# 2104           Agung Setia Budi
# ...                         ...
# 1110          Adhitya Bhawiyuga
# ...

# %%
files.download(output_path)
